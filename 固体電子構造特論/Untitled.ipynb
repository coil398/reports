# %%
import matplotlib.pyplot as plt

# %%
x = range(1, 10)
delta = [12]*9
u_bar = [8]*9
delta_gap = list()
for i in range(1, 5):
    delta_gap.append((12+n))
for i in range(5, 10):
    delta_gap.append((21-n))
corr_gap = [7, 7, 9, 7, 14, 7, 7, 9, 7]

# %%
plt.plot(x, delta, label='Δ')
plt.plot(x, u_bar, label='U bar')
plt.plot(x, delta_gap, label='Δgap')
plt.plot(x, corr_gap, label='Ugap')
plt.legend()

plt.xlabel('The number of electrons.')
plt.ylabel('Energy.')
plt.show()
